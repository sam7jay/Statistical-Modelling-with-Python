# %%
import requests
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
import folium

# Load data from CSV file
csv_file_path = 'G:/Data/Python Project/foursquare.csv'
merge_all_data = pd.read_csv(csv_file_path)

# Check the first 5 rows of the data
print(merge_all_data.head())

# Drop duplicate rows
merge_all_data = merge_all_data.drop_duplicates()

# Drop rows with missing values
merge_all_data = merge_all_data.dropna()

# Save the cleaned data to a new CSV file
output_csv_path = Path('G:/Data/Python Project/EDA_data.csv')
output_csv_path.parent.mkdir(parents=True, exist_ok=True)
merge_all_data.to_csv(output_csv_path, index=False)

# Check the data types of each column
print("Data types of each column:")
print(merge_all_data.dtypes)

# Check for duplicate rows
duplicate_rows_df = merge_all_data[merge_all_data.duplicated()]
print("Number of duplicate rows:", duplicate_rows_df.shape[0])

# Check for missing values
print("Number of missing values in each column:")
print(merge_all_data.isnull().sum())

# Check the data after removing duplicates and missing values
print("Data after removing duplicates and missing values:")
print(merge_all_data.head())
# Out:
#    Unnamed: 0                    fsq_id  category_id   category_name  \
# 0           0  4b65b9f1f964a520fefb2ae3        13031    Burger Joint
# 1           1  4d0cef321f6bf04d75707a31        16037      Playground
# 2           2  4deb8ba688774880e3387c0c        17065  Farmers Market
# 3           3  4fdbc663e4b029940a58c201        16049       Surf Spot
# 4           4  4be3345b660ec928226dcb3b        16017          Garden
#
#                                               chains  distance   latitude  \
# 0  [{'id': 'ab4a3530-d68a-012e-5619-003048cad9da'...        62  43.665065
# 1                                                 []        63  43.664679
# 2                                                 []        40  43.664679
# 3                                                 []       153  43.664482
# 4                                                 []       173  43.665243
#
#    longitude location_country           location_cross_street  \
# 0 -79.319000               CA  btw Queen St. E & Eastern Ave.
# 1 -79.319687               CA                             NaN
# 2 -79.319687               CA                     Dundas St E
# 3 -79.325548               CA                             NaN
# 4 -79.322769               CA                             NaN
#
#                           location_formatted_address location_locality  \
# 0  31 Woodward Ave (btw Queen St. E & Eastern Ave...           Toronto
# 1                20 Woodward Ave, Toronto ON M4L 1A7           Toronto
# 2        150 Greenwood Ave (Dundas St E), Toronto ON           Toronto
# 3                1366 Queen St E, Toronto ON M4L 1C8           Toronto
# 4                1444 Queen St E, Toronto ON M4L 1E1           Toronto
#
#   location_postcode location_region location_timezone  \
# 0           M9N 2J3              ON   America/Toronto
# 1           M4L 1A7              ON   America/Toronto
# 2               NaN              ON   America/Toronto
# 3           M4L 1C8              ON   America/Toronto
# 4           M4L 1E1              ON   America/Toronto
#
#                          name
# 0                  McDonald's
# 1     Jonathan Ashbridge Park
# 2  Leslieville Farmers Market
# 3                   The Beach
# 4        The Ashbridge Estate
# Data types of each column:
# Unnamed: 0                      int64
# fsq_id                         object
# category_id                     int64
# category_name                  object
# chains                         object
# distance                        int64
# latitude                      float64
# longitude                     float64
# location_country               object
# location_cross_street          object
# location_formatted_address     object
# location_locality              object
# location_postcode              object
# location_region                object
# location_timezone              object
# name                           object
# dtype: object
# Number of duplicate rows: 0
# Number of missing values in each column:
# Unnamed: 0                    0
# fsq_id                        0
# category_id                   0
# category_name                 0
# chains                        0
# distance                      0
# latitude                      0
# longitude                     0
# location_country              0
# location_cross_street         0
# location_formatted_address    0
# location_locality             0
# location_postcode             0
# location_region               0
# location_timezone             0
# name                          0
# dtype: int64
# Data after removing duplicates and missing values:
#     Unnamed: 0                    fsq_id  category_id      category_name  \
# 0            0  4b65b9f1f964a520fefb2ae3        13031       Burger Joint
# 11          11  4afb4141f964a520681c22e3        12009          Education
# 14          14  4bd5d73e637ba5931b21f770        17029  Convenience Store
# 15          15  4b52325ef964a5201b6f27e3        11152   Recording Studio
# 17          17  4d6c1a4fdf3d6ea8e4aad926        15007            Dentist
#
#                                                chains  distance   latitude  \
# 0   [{'id': 'ab4a3530-d68a-012e-5619-003048cad9da'...        62  43.665065
# 11                                                 []       546  43.674116
# 14                                                 []       223  43.672605
# 15                                                 []       339  43.668935
# 17                                                 []       178  43.671100
#
#     longitude location_country           location_cross_street  \
# 0  -79.319000               CA  btw Queen St. E & Eastern Ave.
# 11 -79.440446               CA                   Westmount Ave
# 14 -79.441139               CA                        Dufferin
# 15 -79.443730               CA              at Lightbourn Ave.
# 17 -79.447913               CA            St George and Dupont
#
#                            location_formatted_address location_locality  \
# 0   31 Woodward Ave (btw Queen St. E & Eastern Ave...           Toronto
# 11       Regal Rd (Westmount Ave), Toronto ON M6H 2J6           Toronto
# 14   1395 Davenport Rd (Dufferin), Toronto ON M6H 2H6           Toronto
# 15  330 Geary Ave (at Lightbourn Ave.), Toronto ON...           Toronto
# 17  186 Dupont St (St George and Dupont), Toronto ...           Toronto
#
#    location_postcode location_region location_timezone  \
# 0            M9N 2J3              ON   America/Toronto
# 11           M6H 2J6              ON   America/Toronto
# 14           M6H 2H6              ON   America/Toronto
# 15           M6H 2C7              ON   America/Toronto
# 17           M5R 2E6              ON   America/Toronto
#
#                                name
# 0                        McDonald's
# 11  Regal Road Junior Public School
# 14                   QQ Convenience
# 15                Rehearsal Factory
# 17              Dentistry on Dupont

# %%
#importing csv files from previous notebooks

citybike_df = pd.read_csv('G:/Data/Python Project/citybike.csv',index_col=0)
#citybike_df.head()

foursquare_df = pd.read_csv('G:/Data/Python Project/EDA_data.csv',index_col=0)
#foursquare_df.head()


yelp_df = pd.read_csv('G:/Data/Python Project/yelp.csv',index_col=0)
#yelp_df.head()

# %%
def round_coordinates(df, decimals=3):

# Rounds the latitude and longitude of a given DataFrame.

    df['latitude'] = df['latitude'].round(decimals)
    df['longitude'] = df['longitude'].round(decimals)
    return df

# Trim latitude and longitude to increase join match
citybike_df = round_coordinates(citybike_df)
foursquare_df = round_coordinates(foursquare_df)
yelp_df = round_coordinates(yelp_df)

# Merge multiple dataframes
merged_df = pd.merge(citybike_df, foursquare_df, on=['latitude', 'longitude'], how='outer')
merged_df = pd.merge(merged_df, yelp_df, on=['latitude', 'longitude'], how='outer')

# Remove duplicate entries
merged_df = merged_df.drop_duplicates(subset=['latitude', 'longitude', 'fsq_id'], keep='last')

# Show the head of the final merged dataframe
merged_df.head()
# Out:
#                          name_x  latitude  longitude  bikes_available  \
# 19    Queen St E / Woodward Ave    43.665    -79.320              6.0
# 39  Primrose Ave / Davenport Rd    43.671    -79.446              5.0
# 59    Queen St. E / Rhodes Ave.    43.666    -79.318              3.0
# 79         Bond St / Queen St E    43.653    -79.377              2.0
# 99     Church St / Alexander St    43.664    -79.380              4.0
#
#                       fsq_id  category_id         category_name  \
# 19                       NaN          NaN                   NaN
# 39                       NaN          NaN                   NaN
# 59  4e1d9859b0fb93d2d06393c1      11134.0  Pet Grooming Service
# 79                       NaN          NaN                   NaN
# 99  4ad9fc4bf964a520c81c21e3      11045.0                  Bank
#
#                                                chains  distance_x  \
# 19                                                NaN         NaN
# 39                                                NaN         NaN
# 59                                                 []        64.0
# 79                                                NaN         NaN
# 99  [{'id': 'd5192150-d890-0132-61d3-7a163eb2a6fc'...         5.0
#
#    location_country  ... location_postcode location_region location_timezone  \
# 19              NaN  ...               NaN             NaN               NaN
# 39              NaN  ...               NaN             NaN               NaN
# 59               CA  ...           M4L 1G1              ON   America/Toronto
# 79              NaN  ...               NaN             NaN               NaN
# 99               CA  ...           M4Y 2C8              ON   America/Toronto
#
#                   name_y                name rating review_count price  \
# 19                   NaN  Regency Restaurant    4.0         78.0    $$
# 39                   NaN      The Caledonian    4.5        152.0    $$
# 59          Canine Clips   Yaya Greek Bistro    4.0         83.0    $$
# 79                   NaN   Adega Restaurante    4.0        161.0   $$$
# 99  BMO Bank of Montreal      The Carbon Bar    4.0        411.0   $$$
#
#      distance_y  category
# 19   779.013046       NaN
# 39  2619.251867       NaN
# 59  1186.567477       NaN
# 79   692.748189       NaN
# 99  1252.214295       NaN
#
# [5 rows x 23 columns]

# %%
import folium

def create_bike_location_map(df, location_cols, popup_col, zoom_start=13):

#  Create a folium Map and add markers.

    if not set(location_cols + [popup_col]).issubset(df.columns):
        raise ValueError("One or more column names are not in the DataFrame")

    # Create the map centered on the mean coordinates
    center_lat = df[location_cols[0]].mean()
    center_lng = df[location_cols[1]].mean()
    bike_location_map = folium.Map(location=[center_lat, center_lng], zoom_start=zoom_start)

    # Add a marker for each location
    for _, row in df.iterrows():
        location = [row[col] for col in location_cols]
        popup_text = f"{popup_col}: {row[popup_col]}"
        folium.Marker(location=location, popup=popup_text).add_to(bike_location_map)

    return bike_location_map

# Create a map with markers for the bike locations
bike_location_map = create_bike_location_map(merged_df, ['latitude', 'longitude'], 'bikes_available')

# Display the map
bike_location_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_158bd8a519a1c07370e2d4184b9ab66d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_158bd8a519a1c07370e2d4184b9ab66d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_158bd8a519a1c07370e2d4184b9ab66d = L.map(
#                 &quot;map_158bd8a519a1c07370e2d4184b9ab66d&quot;,
#                 {
#                     center: [43.667191027496386, -79.39310274963819],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8a4670193ff6cc1be0ff2b650512e1ae = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_158bd8a519a1c07370e2d4184b9ab66d);
#
#
#             var marker_9941d7b037fff546b81badc41f8b03e1 = L.marker(
#                 [43.665, -79.32],
#                 {}
#             ).addTo(map_158bd8a519a1c07370e2d4184b9ab66d);
#
#
#         var popup_12f524ccd6c369622e822feec7e3edd0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5939cad68d28424b41d7fe4f6b1ff36d = $(`&lt;div id=&quot;html_5939cad68d28424b41d7fe4f6b1ff36d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;bikes_available: 6.0&lt;/div&gt;`)[0];
#                 popup_12f524ccd6c369622e822feec7e3edd0.setContent(html_5939cad68d28424b41d7fe4f6b1ff36d);
#
#
#
#         marker_9941d7b037fff546b81badc41f8b03e1.bindPopup(popup_12f524ccd6c369622e822feec7e3edd0)
#         ;
#
#
#
#
#             var marker_b4b1eef16b805064010fc273ba491ad9 = L.marker(
#                 [43.671, -79.446],
#                 {}
#             ).addTo(map_158bd8a519a1c07370e2d4184b9ab66d);
#
#
#         var popup_2f72f54602f4bbeb8a615a05f3cb5fc8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f1549e489f58ac3c0c39e3b1467f347a = $(`&lt;div id=&quot;html_f1549e489f58ac3c0c39e3b1467f347a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;bikes_available: 5.0&lt;/div&gt;`)[0];
#                 popup_2f72f54602f4bbeb8a615a05f3cb5fc8.setContent(html_f1549e489f58ac3c0c39e3b1467f347a);
#
#
#
#         marker_b4b1eef16b805064010fc273ba491ad9.bindPopup(popup_2f72f54602f4bbeb8a615a05f3cb5fc8)
#         ;
#
#
#
#
#             var marker_e3281fc35da908ff947132ea9a70f6a4 = L.marker(
#                 [43.666, -79.318],
#                 {}
#             ).addTo(map_158bd8a519a1c07370e2d4184b9ab66d);
#
#
#         var popup_19beea9ff6946dcfdc87544273513fdc = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d8dd437bdba7c96c4b3f1d66216ab753 = $(`&lt;div id=&quot;html_d8dd437bdba7c96c4b3f1d66216ab753&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;bikes_available: 3.0&lt;/div&gt;`)[0];
#                 popup_19beea9ff6946dcfdc87544273513fdc.setContent(html_d8dd437bdba7c96c4b3f1d66216ab753);
#
#
#
#         marker_e3281fc35da908ff947132ea9a70f6a4.bindPopup(popup_19beea9ff6946dcfdc87544273513fdc)
#         ;
#
#
#
#
#             var marker_dcfe60ef89efee876b60bafe0e501ba4 = L.marker(
#                 [43.653, -79.377],
#                 {}
#             ).addTo(map_158bd8a519a1c07370e2d4184b9ab66d);
#
#
#         var popup_933803050dba65508d962fb2b9edfa29 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_79f8b4954a3174be8df953981cfbc342 = $(`&lt;div id=&quot;html_79f8b4954a3174be8df953981cfbc342&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;bikes_available: 2.0&lt;/div&gt;`)[0];
#                 popup_933803050dba65508d962fb2b9edfa29.setContent(html_79f8b4954a3174be8df953981cfbc342);
#
#
#
#         marker_dcfe60ef89efee876b60bafe0e501ba4.bindPopup(popup_933803050dba65508d962fb2b9edfa29)
#         ;
#
#
#
#
#             var marker_876dd6c144e5be07e742fed94bcc6e53 = L.marker(
#                 [43.664, -79.38],
#                 {}
#             ).addTo(map_158bd8a519a1c07370e2d4184b9ab66d);
#
#
#         var popup_1e13446aa66132bbbca0be40f0288b98 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_67c6d2c8d64a41955815232876253466 = $(`&lt;div id=&quot;html_67c6d2c8d64a41955815232876253466&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;bikes_available: 4.0&lt;/div&gt;`)[0];
#                 popup_1e13446aa66132bbbca0be40f0288b98.setContent(html_67c6d2c8d64a41955815232876253466);
#
#
#
#         marker_876dd6c144e5be07e742fed94bcc6e53.bindPopup(popup_1e13446aa66132bbbca0be40f0288b98)
#         ;
#
#
#
#
#             var marker_79a4e79605f8c5410fad5d9e7e05c875 = L.marker(
#                 [43.664, -79.3

# %%
import matplotlib.pyplot as plt

def plot_average_bikes(df, group_col, value_col, figsize=(10, 8), color='skyblue'):
 #plot a sorted bar chart.

    if not set([group_col, value_col]).issubset(df.columns):
        raise ValueError("One or more column names are not in the DataFrame")

    grouped = df.groupby(group_col)[value_col].mean().sort_values(ascending=False)

    plt.figure(figsize=figsize)
    grouped.plot(kind='barh', color=color)
    plt.xlabel('Average Number of Bikes Available')
    plt.ylabel('Location')
    plt.title('Average Bikes Available by Location')
    plt.gca().invert_yaxis()  # Reverse the order of the y-axis
    plt.show()

# Call the function to plot average bikes available by location
plot_average_bikes(merged_df, 'category_name', 'bikes_available')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

def plot_scatter_with_regression(df, x_col, y_col, figsize=(8, 6)):

   # Plot a scatter chart with a regression line with the specified DataFrame, x column, and y column.

    if not set([x_col, y_col]).issubset(df.columns):
        raise ValueError("One or more column names are not in the DataFrame")

    plt.figure(figsize=figsize)
    sns.regplot(x=x_col, y=y_col, data=df, line_kws={'color': 'red'})
    plt.xlabel('Distance')
    plt.ylabel('Bikes available')
    plt.title('Bikes available vs. distance')
    plt.show()

# Call the function to plot bikes available versus distance
plot_scatter_with_regression(merged_df, 'distance_x', 'bikes_available')

# %%
import sqlite3

# Connect to an SQLite database in a specific directory
conn = sqlite3.connect('G:/Data/Python Project/database.sqlite')

# Store the Pandas dataframe into the SQLite database
merged_df.to_sql('merged_data', conn, if_exists='replace')

# Write the SQL query
query = "SELECT * FROM merged_data"

# Use pd.read_sql_query to query the database and put the result into a DataFrame
df = pd.read_sql_query(query, conn)

# Display the DataFrame
print(df)

# Remember to close the connection when done
conn.close()
# Out:
#      index                       name_x  latitude  longitude  bikes_available  \
# 0       19    Queen St E / Woodward Ave    43.665    -79.320              6.0
# 1       39  Primrose Ave / Davenport Rd    43.671    -79.446              5.0
# 2       59    Queen St. E / Rhodes Ave.    43.666    -79.318              3.0
# 3       79         Bond St / Queen St E    43.653    -79.377              2.0
# 4       99     Church St / Alexander St    43.664    -79.380              4.0
# ..     ...                          ...       ...        ...              ...
# 686   1042                         None    43.676    -79.390              NaN
# 687   1043                         None    43.674    -79.390              NaN
# 688   1044                         None    43.675    -79.397              NaN
# 689   1045                         None    43.675    -79.397              NaN
# 690   1046                         None    43.674    -79.396              NaN
#
#                        fsq_id  category_id         category_name  \
# 0                        None          NaN                  None
# 1                        None          NaN                  None
# 2    4e1d9859b0fb93d2d06393c1      11134.0  Pet Grooming Service
# 3                        None          NaN                  None
# 4    4ad9fc4bf964a520c81c21e3      11045.0                  Bank
# ..                        ...          ...                   ...
# 686  4af6de52f964a520b20322e3      16032.0                  Park
# 687  4b81644af964a52049a330e3      15054.0          Veterinarian
# 688  4bec8ab849430f478ee507d2      11090.0     Interior Designer
# 689  4c45ac15429a0f47c0684a1e      17029.0     Convenience Store
# 690  4b04191df964a5205c5122e3      11045.0                  Bank
#
#                                                 chains  distance_x  ...  \
# 0                                                 None         NaN  ...
# 1                                                 None         NaN  ...
# 2                                                   []        64.0  ...
# 3                                                 None         NaN  ...
# 4    [{'id': 'd5192150-d890-0132-61d3-7a163eb2a6fc'...         5.0  ...
# ..                                                 ...         ...  ...
# 686                                                 []        93.0  ...
# 687                                                 []       182.0  ...
# 688                                                 []        81.0  ...
# 689                                                 []        71.0  ...
# 690  [{'id': 'd51aa7f0-d890-0132-61d3-7a163eb2a6fc'...        45.0  ...
#
#     location_postcode location_region location_timezone  \
# 0                None            None              None
# 1                None            None              None
# 2             M4L 1G1              ON   America/Toronto
# 3                None            None              None
# 4             M4Y 2C8              ON   America/Toronto
# ..                ...             ...               ...
# 686           M6E 2N1              ON   America/Toronto
# 687           M4W 3C7              ON   America/Toronto
# 688           M5R 1J6              ON   America/Toronto
# 689           M5R 2H8              ON   America/Toronto
# 690           M5R 3S4              ON   America/Toronto
#
#                                 name_y                name rating  \
# 0                                 None  Regency Restaurant    4.0
# 1                                 None      The Caledonian    4.5
# 2                         Canine Clips   Yaya Greek Bistro    4.0
# 3                                 None   Adega Restaurante    4.0
# 4                 BMO Bank of Montreal      The Carbon Bar    4.0
# ..                                 ...                 ...    ...
# 686                       Ramsden Park                None    NaN
# 687  VEC - Veterinary Emergency Clinic                None    NaN
# 688     Gluckstein Design Planning Inc                None    NaN
# 689                  Super Convenience                None    NaN
# 690            TD Bank Financial Group                None    NaN
#
#     review_count price   distance_y  category
# 0           78.0    $$   779.013046      None
# 1          152.0    $$  2619.251867      None
# 2           83.0    $$  1186.567477      None
# 3          161.0   $$$   692.748189      None
# 4          411.0   $$$  1252.214295      None
# ..           ...   ...          ...       ...
# 686          NaN  None          NaN      None
# 687          NaN  None          NaN      None
# 688          NaN  None          NaN      None
# 689          NaN  None          NaN      None
# 690          NaN  None          NaN      None
#
# [691 rows x 24 columns]
